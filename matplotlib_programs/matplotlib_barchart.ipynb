# %% [markdown]
# ```
#     @Author: Nishanth
#     @Date: 09-04-2022 17:21:00
#     @Last Modified by: Nishanth
#     @Last Modified date: 09-04-2022 18:33:00
#     @Title: Practice problems on matplolib barcharts
# ```

# %% [markdown]
# **Import required libraries**

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. **Write a Python programming to display a bar chart of the popularity of programming Languages**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a bar chart of programming languages vs popularity
programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(programming_languages, popularity)
plt.title('Popularity of programming languages')
plt.ylabel('Popularity level')
plt.show()

# %% [markdown]
# 2. **Write a Python programming to display a horizontal bar chart of the popularity of programming Languages**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a horizantal bar chart
plt.barh(programming_languages, popularity)
plt.title('Popularity of programming languages')
plt.xlabel('Popularity level')
plt.show()

# %% [markdown]
# 3. **Write a Python programming to display a bar chart of the popularity of programming Languages. Use uniform color**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a horizantal bar chart with uniform color
plt.barh(programming_languages, popularity, color = (0.2, 0.2, 0.6, 0.6))
plt.title('Popularity of programming languages')
plt.xlabel('Popularity level')
plt.show()

# %% [markdown]
# 4. **Write a Python programming to display a bar chart of the popularity of programming Languages. Use different color for each bar**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a horizantal bar chart with different colors
plt.barh(programming_languages, popularity, color = ['red', 'blue', 'green', 'cyan', 'orange', 'brown'])
plt.title('Popularity of programming languages')
plt.xlabel('Popularity level')
plt.show()

# %% [markdown]
# 5. **Write a Python programming to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value)**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a horizantal bar chart with values
plt.barh(programming_languages, popularity)
plt.title('Popularity of programming languages')
plt.xlabel('Popularity level')

# Display value text for each bar
for index, value in enumerate(popularity):
    plt.text(value, index, str(value))

plt.show()

# %% [markdown]
# 6. **Write a Python programming to display a bar chart of the popularity of programming Languages. Make blue border to each bar**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Plot a horizantal bar chart with values
plt.barh(programming_languages, popularity, edgecolor = 'b', linewidth = 3)
plt.title('Popularity of programming languages')
plt.xlabel('Popularity level')

plt.show()

# %% [markdown]
# 7. **Write a Python programming to display a bar chart of the popularity of programming Languages. Specify the position of each bar plot**
#
#     Sample data:\
#     Programming languages: Java, Python, PHP, JavaScript, C#, C++\
#     Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# Give position for x labels using x ticks
positions = [0,1,2,3,4,5]
bar_pos = [0.05,0.95,2.05,2.95,4.05,4.95]
plt.xticks(positions, labels=programming_languages)

# Give bar positions
plt.bar(bar_pos, popularity)
plt.title('Popularity of programming languages')
plt.ylabel('Popularity level')
plt.show()

# %% [markdown]
# 8. **Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions**

# %%
# Give position for x labels using x ticks
positions = [0,1,2,3,4,5]
bar_width = [0.8,0.7,0.6,0.5,0.4,0.3]
bar_pos = [0.1,0.9,2.1,2.9,4.1,4.9]
plt.xticks(positions, labels=programming_languages)

# Give bar positions and bar width
plt.bar(bar_pos, popularity, width=bar_width)
plt.title('Popularity of programming languages')
plt.ylabel('Popularity level')
plt.show()

# %% [markdown]
# 9. **Write a Python programming to display a bar chart of the popularity of programming Languages. Increase bottom margin**

# %%
# increase bottom of the bar margins
plt.bar(programming_languages, popularity, bottom=4)
plt.title('Popularity of programming languages')
plt.ylabel('Popularity level')
plt.show()

# %% [markdown]
# 10. **Write a Python program to create bar plot of scores by group and gender. Use multiple X values on the same chart for men and women**
#
#     Sample Data:\
#     Means (men) = (22, 30, 35, 35, 26)\
#     Means (women) = (25, 32, 30, 35, 29)

# %%
# Create list of mens and womens means values
men_means = [22, 30, 35, 35, 26]
women_means = [25, 32, 30, 35, 29]
x_labels = ['group1', 'group2', 'group3', 'group4', 'group5']

x_val = np.arange(len(men_means))

# plot bars for men and women on same chart
plt.bar(x_val - 0.2, men_means, color = 'b', width=0.4, label='Men')
plt.bar(x_val + 0.2, women_means, color = 'r', width=0.4, label='Women')
plt.xticks(x_val, x_labels)
plt.legend(loc='upper left')
plt.title('Men vs Women average scores')
plt.show()

# %% [markdown]
# 11. **Write a Python program to create bar plot from a DataFrame**
#
#     Sample Data Frame:\
#     a b c d e\
#     2 4,8,5,7,6\
#     4 2,3,4,2,6\
#     6 4,7,4,7,8\
#     8 2,6,4,8,6\
#     10 2,4,3,3,2

# %%
# Create the given dataframe
dataframe = pd.read_csv('sample_df.csv', )
dataframe.set_index(np.arange(2, 11, 2), inplace=True)

x_labels = ['g1', 'g2', 'g3', 'g4', 'g5']

x_val = np.arange(0,10, step=2)

# plot bars for a,b,c,d,e on same chart
plt.bar(x_val - 0.6, dataframe['a'], color = 'blue', width=0.3, label='a')
plt.bar(x_val - 0.3, dataframe['b'], color = 'red', width=0.3, label='b')
plt.bar(x_val, dataframe['c'], color = 'green', width=0.3, label='c')
plt.bar(x_val + 0.3, dataframe['d'], color = 'orange', width=0.3, label='d')
plt.bar(x_val + 0.6, dataframe['e'], color = 'cyan', width=0.3, label='e')
plt.xticks(x_val, x_labels)
plt.legend()
plt.title('bar plot of sample data frame')
plt.xlabel('Groups')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# 12. **Write a Python program to create bar plots with error bars on the same figure**
#
#     Sample Date\
#     Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824\
#     Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
Mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
std_dev_velocity= [0.3314, 0.2278, 0.2836, 0.2645]

x_val = ['velocity1', 'velocity2', 'velocity3', 'velocity4']

# Plot the mean bar chart
plt.bar(x_val, Mean_velocity, label='mean velocity')

# Plot the errorbar using the std dev
plt.errorbar(x_val, Mean_velocity, yerr=std_dev_velocity, label='Std deviation', color='r', fmt='o')
plt.xlabel('Velocity groups')
plt.ylabel('Mean values')
plt.legend()
plt.show()
